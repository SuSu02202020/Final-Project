# %%
import pandas as pd
import os

# %%
data = pd.read_csv('total_city.csv', header=0)

# %%
data
# Out:
#       Unnamed: 0 ZIPCODE Total Annual Payroll Population Median Age  \
# 0            0.0   10001              8717306      21966       34.7
# 1            1.0   10002               617348      82191       39.8
# 2            2.0   10003              6479129      57310       32.3
# 3            3.0   10004              9308424       2807       33.1
# 4            4.0   10005              6325335       6822       28.6
# 5            5.0   10006              2210783       2507       31.3
# 6            6.0   10007              2440063       6525         34
# 7            7.0   10009               389801      62810       36.3
# 8            8.0   10010              8554029      30670       35.1
# 9            9.0   10011              4502863      52167       39.7
# 10          10.0   10012              2186536      26145       34.1
# 11          11.0   10013              6896775      26065       36.4
# 12          12.0   10014              2728947      30597       36.7
# ...

# %%
null = data.isnull()
null
# Out:
#       Unnamed: 0  ZIPCODE  Total Annual Payroll  Population  Median Age  \
# 0          False    False                 False       False       False
# 1          False    False                 False       False       False
# 2          False    False                 False       False       False
# 3          False    False                 False       False       False
# 4          False    False                 False       False       False
# 5          False    False                 False       False       False
# 6          False    False                 False       False       False
# 7          False    False                 False       False       False
# 8          False    False                 False       False       False
# 9          False    False                 False       False       False
# 10         False    False                 False       False       False
# 11         False    False                 False       False       False
# ...

# %%
df = data.fillna('Info not available')
df
# Out:
#      Unnamed: 0 ZIPCODE Total Annual Payroll Population          Median Age  \
# 0             0   10001              8717306      21966                34.7
# 1             1   10002               617348      82191                39.8
# 2             2   10003              6479129      57310                32.3
# 3             3   10004              9308424       2807                33.1
# 4             4   10005              6325335       6822                28.6
# 5             5   10006              2210783       2507                31.3
# 6             6   10007              2440063       6525                  34
# 7             7   10009               389801      62810                36.3
# 8             8   10010              8554029      30670                35.1
# 9             9   10011              4502863      52167                39.7
# 10           10   10012              2186536      26145                34.1
# ...

# %%
df.to_csv("clean_total_city.csv")
